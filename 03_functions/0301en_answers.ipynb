# %% [markdown]
# # `Quick assignment 1: Function Definition Structure`

# %%
def is_even_or_odd(number):
    if number % 2 == 0:
        print(number, "is even.")
    else:
        print(number, "is odd.")

is_even_or_odd(14)
# Out:
# Running cells with 'c:\Users\woite\AppData\Local\Programs\Python\Python312\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/woite/AppData/Local/Programs/Python/Python312/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# # `Quick Assignment 3: Check if Positive`

# %%
def is_positive(number):
    if number > 0:
        print(number, "is positive.")
    else:
        print(number, "is not positive.")

is_positive(-5)

# %% [markdown]
# # `Quick Assignment 4: Check if Greater Than`

# %%
def is_greater_than(number, limit):
    if number > limit:
        print(number, "is greater than", limit)
    else:
        print(number, "is not greater than", limit)

is_greater_than(8, 10)
